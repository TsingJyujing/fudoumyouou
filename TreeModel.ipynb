# %%
import datetime
from math import sqrt

import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from domus_analytica.config import DomusSettings
from domus_analytica.data_clean import extract_info_to_table

config = DomusSettings(_env_file=".env.local")

# %% [markdown]
# # Extract Data and Preprocessing

# %%
def data_preprocessing(data: pd.DataFrame):
    # Data preprocessing
    data["unit_price"] = data["price"] / data["exclusive_area"]
    data["completion_date_number"] = (
            pd.to_datetime(data["completion_date"]).astype(int)
            / (10 ** 9 * (24 * 60 * 60) * 365.25)
            + 1970
    )
    data["min_distance_to_busy_area"] = data[
        ["distance_to_hakata",
         "distance_to_ohori_park",
         "distance_to_tenjin"]
    ].min(axis=1)
    data["floor_ratio"] = data["floor"] * 1.0 / data["total_floors"]

    def direction_mapping(s: str) -> str:
        return s.replace("東", "E").replace("南", "S").replace("西", "W").replace("北", "N")

    data["direction"] = data["direction"].map(direction_mapping)

    data = pd.get_dummies(data, columns=["direction"], dtype="float32")
    data = pd.get_dummies(data, columns=["layout_main"], dtype="float32")
    data = pd.get_dummies(data, columns=["build_type"], dtype="float32")

    return data


df = data_preprocessing(
    extract_info_to_table(
        config,
        {'search_time': datetime.datetime(2024, 4, 1, 14, 46, 31, 449000)}
    )
)
df.head().transpose()
# Out:
#                                                                              0  \
# id                           /ms/chuko/fukuoka/sc_fukuokashihigashi/nc_7437...
# name                                                    モントーレブルー・ラ・メール Fukuoka
# address                                                      福岡県福岡市東区西戸崎２-1-30
# lat                                                           33.6461037815746
# lon                                                             130.3599501447
# price                                                                   2080.0
# exclusive_area                                                           57.25
# common_area                                                              11.04
# completion_date                                                     2007-01-01
# layout_storage_room                                                          0
# pet                                                                      False
# floor                                                                       10
# total_floors                                                                14
# restaurant_count                                                             7
# supermarket_count                                                            1
# convenience_store_count                                                      0
# drugstore_count                                                              0
# park_count                                                                  14
# cafe_count                                                                   3
# bus_station_count                                                            0
# primary_school_count                                                         0
# distance_to_nearest_station                                           0.502634
# distance_to_tenjin                                                    7.085989
# distance_to_hakata                                                    8.566679
# distance_to_ohori_park                                                6.455506
# min_distance_to_mafia                                                 6.369879
# min_distance_to_cemetery                                              5.105502
# monthly_fee_manage                                                      7800.0
# monthly_fee_repair                                                      3400.0
# monthly_fee_repair_fund                                                      0
# monthly_fee_others                                                       800.0
# monthly_fee_total                                                      12000.0
# unit_price                                                           36.331878
# completion_date_number                                             2006.999316
# min_distance_to_busy_area                                             6.455506
# floor_ratio                                                           0.714286
# direction_E                                                                0.0
# direction_N                                                                0.0
# direction_NE                                                               0.0
# direction_NW                                                               0.0
# direction_S                                                                1.0
# direction_SE                                                               0.0
# direction_SW                                                               0.0
# direction_W                                                                0.0
# layout_main_2DK                                                            0.0
# layout_main_2LDK                                                           1.0
# layout_main_3LDK                                                           0.0
# layout_main_3LK                                                            0.0
# layout_main_4LDK                                                           0.0
# build_type_RC                                                              1.0
# build_type_unknown                                                         0.0
# build_type_wood                                                            0.0
#
#                                                                              1  \
# id                           /ms/chuko/fukuoka/sc_fukuokashihigashi/nc_7460...
# name                                                                ファーネスト箱崎公園
# address                                                            福岡県福岡市東区松田２
# lat                                                           33.6203572036973
# lon                                                           130.443550474538
# price                                                                   2080.0
# exclusive_area                                                           69.85
# common_area                                                               38.1
# completion_date                                                     2008-06-01
# layout_storage_room                                                          0
# pet                                                                      False
# floor                                                                        7
# total_floors                                                                10
# restaurant_count                                                            60
# supermarket_count                                                            8
# convenience_store_count                                                     16
# drugstore_count                                                              2
# park_count                                                                  35
# cafe_count                                                                   4
# bus_station_count                                                            0
# primary_school_count                                                         1
# distance_to_nearest_station                                           0.804436
# distance_to_tenjin                                                    5.285324
# distance_to_hakata                                                    4.284875
# distance_to_ohori_park                                                6.865806
# min_distance_to_mafia                                                 3.216888
# min_distance_to_cemetery                                               0.57486
# monthly_fee_manage                                                      7600.0
# monthly_fee_repair                                                      9100.0
# monthly_fee_repair_fund                                                      0
# monthly_fee_others                                                         0.0
# monthly_fee_total                                                      16700.0
# unit_price                                                           29.778096
# completion_date_number                                             2008.414784
# min_distance_to_busy_area                                             4.284875
# floor_ratio                                                                0.7
# direction_E                                                                0.0
# direction_N                                                                0.0
# direction_NE                                                               0.0
# direction_NW                                                               1.0
# direction_S                                                                0.0
# direction_SE                                                               0.0
# direction_SW                                                               0.0
# direction_W                                                                0.0
# layout_main_2DK                                                            0.0
# layout_main_2LDK                                                           0.0
# layout_main_3LDK                                                           1.0
# layout_main_3LK                                                            0.0
# layout_main_4LDK                                                           0.0
# build_type_RC                                                              1.0
# build_type_unknown                                                         0.0
# build_type_wood                                                            0.0
#
#                                                                              2  \
# id                           /ms/chuko/fukuoka/sc_fukuokashihigashi/nc_7250...
# name                                                      Asobi+　JGMヴェルデ香椎南弐番館
# address                                                            福岡県福岡市東区八田１
# lat                                                             33.63406257298
# lon                                                           130.456704058744
# price                                                                   2490.0
# exclusive_area                                                           93.33
# common_area                                                              24.55
# completion_date                                                     2001-06-01
# layout_storage_room                                                          0
# pet                                                                      False
# floor                                                                        2
# total_floors                                                                 9
# restaurant_count                                                            59
# supermarket_count                                                            5
# convenience_store_count                                                      8
# drugstore_count                                                              7
# park_count                                                                  22
# cafe_count                                                                   8
# bus_station_count                                                            0
# primary_school_count                                                         4
# distance_to_nearest_station                                           0.875963
# distance_to_tenjin                                                    7.199107
# distance_to_hakata                                                    6.226393
# distance_to_ohori_park                                                8.705188
# min_distance_to_mafia                                                 5.031993
# min_distance_to_cemetery                                              0.666798
# monthly_fee_manage                                                      7500.0
# monthly_fee_repair                                                     14900.0
# monthly_fee_repair_fund                                                      0
# monthly_fee_others                                                         0.0
# monthly_fee_total                                                      22400.0
# unit_price                                                           26.679524
# completion_date_number                                               2001.4141
# min_distance_to_busy_area                                             6.226393
# floor_ratio                                                           0.222222
# direction_E                                                                0.0
# direction_N                                                                0.0
# direction_NE                                                               0.0
# direction_NW                                                               0.0
# direction_S                                                                0.0
# direction_SE                                                               1.0
# direction_SW                                                               0.0
# direction_W                                                                0.0
# layout_main_2DK                                                            0.0
# layout_main_2LDK                                                           0.0
# layout_main_3LDK                                                           0.0
# layout_main_3LK                                                            0.0
# layout_main_4LDK                                                           1.0
# build_type_RC                                                              1.0
# build_type_unknown                                                         0.0
# build_type_wood                                                            0.0
#
#                                                                              3  \
# id                           /ms/chuko/fukuoka/sc_fukuokashiminami/nc_73552...
# name                                                        エイルヴィラクレアテュール井尻南II
# address                                                            福岡県福岡市南区曰佐２
# lat                                                            33.540890670713
# lon                                                           130.438664435095
# price                                                                   2580.0
# exclusive_area                                                           75.42
# common_area                                                              20.88
# completion_date                                                     1999-05-01
# layout_storage_room                                                          0
# pet                                                                      False
# floor                                                                        5
# total_floors                                                                 6
# restaurant_count                                                            60
# supermarket_count                                                            6
# convenience_store_count                                                     16
# drugstore_count                                                              3
# park_count                                                                  40
# cafe_count                                                                  18
# bus_station_count                                                            0
# primary_school_count                                                         5
# distance_to_nearest_station                                           1.319945
# distance_to_tenjin                                                    6.720793
# distance_to_hakata                                                    5.468257
# distance_to_ohori_park                                                 7.81053
# min_distance_to_mafia                                                  7.93783
# min_distance_to_cemetery                                              1.582766
# monthly_fee_manage                                                      7430.0
# monthly_fee_repair                                                      8300.0
# monthly_fee_repair_fund                                                      0
# monthly_fee_others                                                         0.0
# monthly_fee_total                                                      15730.0
# unit_price                                                           34.208433
# completion_date_number                                             1999.327858
# min_distance_to_busy_area                                             5.468257
# floor_ratio                                                           0.833333
# direction_E                                                                0.0
# direction_N                                                                0.0
# direction_NE                                                               0.0
# direction_NW                                                               0.0
# direction_S                                                                0.0
# direction_SE                                                               0.0
# direction_SW                                                               1.0
# direction_W                                                                0.0
# layout_main_2DK                                                            0.0
# layout_main_2LDK                                                           0.0
# layout_main_3LDK                                                           1.0
# layout_main_3LK                                                            0.0
# layout_main_4LDK                                                           0.0
# build_type_RC                                                              1.0
# build_type_unknown                                                         0.0
# build_type_wood                                                            0.0
#
#                                                                              4
# id                           /ms/chuko/fukuoka/sc_fukuokashihakata/nc_74582...
# name                                                                   アンピール吉塚
# address                                                           福岡県福岡市博多区吉塚６
# lat                                                           33.6075918806721
# lon                                                           130.429482478425
# price                                                                   2780.0
# exclusive_area                                                            65.1
# common_area                                                               14.0
# completion_date                                                     2000-11-01
# layout_storage_room                                                          0
# pet                                                                      False
# floor                                                                        3
# total_floors                                                                11
# restaurant_count                                                            60
# supermarket_count                                                            2
# convenience_store_count                                                     19
# drugstore_count                                                              5
# park_count                                                                  46
# cafe_count                                                                  16
# bus_station_count                                                            0
# primary_school_count                                                         7
# distance_to_nearest_station                                           0.548731
# distance_to_tenjin                                                     3.39822
# distance_to_hakata                                                    2.424849
# distance_to_ohori_park                                                5.070826
# min_distance_to_mafia                                                 1.638501
# min_distance_to_cemetery                                              0.319586
# monthly_fee_manage                                                      5200.0
# monthly_fee_repair                                                      6840.0
# monthly_fee_repair_fund                                                      0
# monthly_fee_others                                                         0.0
# monthly_fee_total                                                      12040.0
# unit_price                                                           42.703533
# completion_date_number                                             2000.833676
# min_distance_to_busy_area                                             2.424849
# floor_ratio                                                           0.272727
# direction_E                                                                0.0
# direction_N                                                                0.0
# direction_NE                                                               0.0
# direction_NW                                                               0.0
# direction_S                                                                0.0
# direction_SE                                                               1.0
# direction_SW                                                               0.0
# direction_W                                                                0.0
# layout_main_2DK                                                            0.0
# layout_main_2LDK                                                           0.0
# layout_main_3LDK                                                           1.0
# layout_main_3LK                                                            0.0
# layout_main_4LDK                                                           0.0
# build_type_RC                                                              1.0
# build_type_unknown                                                         0.0
# build_type_wood                                                            0.0

# %% [markdown]
# # Train model to predict unit price

# %%
from sklearn.tree import DecisionTreeRegressor
from itertools import chain
import pandas as pd

feature_prefixes = ["direction_", "layout_main_", "build_type_"]
features = list(set(chain(
    [
        "min_distance_to_busy_area",
        "distance_to_nearest_station",
        "distance_to_hakata",
        "distance_to_ohori_park",
        "distance_to_tenjin",
        "min_distance_to_mafia",
        "min_distance_to_cemetery",
    ],
    [
        "bus_station_count",
        "restaurant_count",
        "supermarket_count",
        "convenience_store_count",
        "drugstore_count",
        "park_count",
        "cafe_count",
        "floor",
        "total_floors",
        "floor_ratio",
        "common_area",
        "layout_storage_room",
        "exclusive_area",
        "completion_date_number",
        "monthly_fee_total",
    ],
    *(
        [col for col in df.columns if col.startswith(feature_prefix)]
        for feature_prefix in feature_prefixes
    )
)))
target = "unit_price"

print("Using features: {} to predict {}".format(",".join(features), target))

X_train, X_test, y_train, y_test = train_test_split(
    df[features], df[target], test_size=0.1, random_state=123
)

model = DecisionTreeRegressor(max_depth=7, max_leaf_nodes=28)
model.fit(X_train, y_train)
print(
    f"R-Square: Train={model.score(X_train, y_train)}, test={model.score(X_test, y_test)}"
)
print(
    f"単価のRMSE (万円): Train={sqrt(mean_squared_error(model.predict(X_train), y_train))}, test={sqrt(mean_squared_error(model.predict(X_test), y_test))}"
)

total_rmse_train = sqrt(
    mean_squared_error(
        model.predict(X_train) * X_train["exclusive_area"],
        y_train * X_train["exclusive_area"],
    )
)
total_rmse_test = sqrt(
    mean_squared_error(
        model.predict(X_test) * X_test["exclusive_area"],
        y_test * X_test["exclusive_area"],
    )
)
print(f"総金額のRMSE (万円): Train={total_rmse_train}, test={total_rmse_test}")
df["unit_price_estimate"] = model.predict(df[features])
df["price_estimate"] = df["unit_price_estimate"] * df["exclusive_area"]

from sklearn.tree import plot_tree
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = [64, 16]
_ = plot_tree(model, feature_names=features, fontsize=13, rounded=True)
plt.savefig("output/tree_model.png")
model
# Out:
# Using features: direction_W,monthly_fee_total,direction_NW,min_distance_to_cemetery,direction_SE,restaurant_count,distance_to_nearest_station,distance_to_tenjin,layout_main_3LDK,min_distance_to_mafia,floor,floor_ratio,common_area,exclusive_area,direction_S,build_type_unknown,direction_E,build_type_wood,drugstore_count,cafe_count,layout_main_2LDK,supermarket_count,direction_N,layout_main_3LK,total_floors,park_count,direction_SW,build_type_RC,direction_NE,bus_station_count,layout_main_2DK,convenience_store_count,min_distance_to_busy_area,distance_to_hakata,layout_main_4LDK,distance_to_ohori_park,completion_date_number,layout_storage_room to predict unit_price
# R-Square: Train=0.8842400930427137, test=0.7299562525814518
# 単価のRMSE (万円): Train=5.796757734345518, test=8.078520009375964
# 総金額のRMSE (万円): Train=474.5736745168438, test=672.4387013775274
# DecisionTreeRegressor(max_depth=7, max_leaf_nodes=28)

# %% [markdown]
# # Error Analysis
#
# ## Error Visualization for unit price

# %%
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(12, 6))
[ax1, ax2] = fig.subplots(1, 2)
_ = ax1.scatter(df["unit_price"], df["unit_price_estimate"], c=df["exclusive_area"], cmap="gray")
ax1.set_xlabel("Real unit price")
ax1.set_ylabel("Estimated unit price")
unit_price_error = df["unit_price"] - df["unit_price_estimate"]
_ = ax2.hist(unit_price_error, bins=30)
ax2.set_xlabel("Error of prediction")
ax2.set_ylabel("Count")
print(f"Mu={unit_price_error.to_numpy().mean()} Std={unit_price_error.to_numpy().std()}")
# Out:
# Mu=-0.06779756320089084 Std=6.0669252472264015

# %% [markdown]
# ## Error Analysis for Total Price

# %%
fig = plt.figure(figsize=(12, 6))
[ax1, ax2] = fig.subplots(1, 2)
_ = ax1.scatter(df["price"], df["price_estimate"], c=df["exclusive_area"], cmap="gray")
ax1.set_xlabel("Real price")
ax1.set_ylabel("Estimated price")
price_error = df["price"] - df["price_estimate"]
_ = ax2.hist(price_error, bins=30)
ax2.set_xlabel("Error of prediction")
ax2.set_ylabel("Count")
print(f"Mu={price_error.to_numpy().mean()} Std={price_error.to_numpy().std()}")
# Out:
# Mu=-9.582557475644753 Std=498.13398938272314

# %% [markdown]
# ## Distribution for CP value
#
# CP value is the ration between estimated price and real price.
# It assumes that the model's predictions are fundamentally accurate, and that the prediction errors come from different sellers' psychological expectations.
#
# When we have a model that also works well on the test set, we can use CP Value to estimate the profit margin.

# %%
plt.rcParams['figure.figsize'] = [12, 6]
df["cp_value"] = df["price_estimate"] * 100.0 / df["price"]
_ = plt.hist(df["cp_value"], bins=50)
plt.xlabel("CP Value")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Save The Result
#
# Save the result to CSV file and order by CP value desc.

# %%
df.sort_values(by=["cp_value"], ascending=False).to_csv("data/tree-result.csv", index=False)
